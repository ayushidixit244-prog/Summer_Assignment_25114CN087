# %%
#Question-89:Find first non-repeating character in a string.
s = "pomegranate"
char_count = {}
for char in s:                           # Count the occurrences of each character  
    if char in char_count:
         char_count[char] += 1            
    else:
         char_count[char] = 1
for char in s:                                      # Find the first non-repeating character
    if char_count[char] == 1:
        print(f"The first non-repeating character is: {char}")
        break
else:
    print("There is no non-repeating character in the string.")

# %%
#Question-90:To find the first repeating character in a string.
s = "pomegranate"
char_count = {}
for char in s:
    if char in char_count:
        char_count[char] += 1
    else:
        char_count[char] = 1
for char in s:
    if char_count[char] > 1:
        print(f"The first repeating character is: {char}")
        break
else:
    print("There is no repeating character in the string.")

# %%
#Question-91:To check if two strings are anagrams of each other.
s1 = "listen"
s2 = "silent"
if sorted(s1) == sorted(s2):
    print(f"The strings '{s1}' and '{s2}' are anagrams of each other.")
else:
    print(f"The strings '{s1}' and '{s2}' are not anagrams of each other.")

# %%
#Question-92:Find maximum occuring character in a string.
s = "pomegranate"
char_count = {}
for char in s:
    if char in char_count:
        char_count[char] += 1
    else:
        char_count[char] = 1
max_char = max(char_count, key=char_count.get)              #The character with the maximum occurrence
print(f"The maximum occurring character is: {max_char} which appears {char_count[max_char]} times.")
