# %%
#Question-105:To create student record management system.
students = []

def add_student():
    name = input("Enter student name: ")
    age = int(input("Enter student age: "))
    grade = input("Enter student grade: ")
    student = {"name": name, "age": age, "grade": grade}
    students.append(student)
    print("Student added successfully!")

def view_students():
    if not students:
        print("No students in the record.")
    else:
        for i, student in enumerate(students, start=1):
            print(f"Student {i}:")
            for key, value in student.items():
                print(f"  {key}: {value}")
            print()

def main():
    while True:
        print("1. Add Student")
        print("2. View Students")
        print("3. Exit")
        choice = input("Enter your choice: ")
        if choice == '1':
            add_student()
        elif choice == '2':
            view_students()
        elif choice == '3':
            print("Thank you for using the Student Record Management System. Goodbye!")
            break
        else:
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    main()

# %%
#Question-106:To create employee management system.
employees = []  

def add_employee():
    name = input("Enter employee name: ")
    age = int(input("Enter employee age: "))
    position = input("Enter employee position: ")
    employee = {"name": name, "age": age, "position": position}
    employees.append(employee)
    print("Employee added successfully!")

def view_employees():
    if not employees:
        print("No employees in the record.")
    else:
        for i, employee in enumerate(employees, start=1):
            print(f"Employee {i}:")
            for key, value in employee.items():
                print(f"  {key}: {value}")
            print()

def main():
    while True:
        print("1. Add Employee")
        print("2. View Employees")
        print("3. Exit")
        choice = input("Enter your choice: ")
        if choice == '1':
            add_employee()
        elif choice == '2':
            view_employees()
        elif choice == '3':
            print("Thank you for using the Employee Management System. Goodbye!")
            break
        else:
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    main()

# %%
#Question-107:To create salary management system.
salaries = []

def add_salary():
    employee_name = input("Enter employee name: ")
    salary = float(input("Enter salary: "))
    salaries.append({"employee_name": employee_name, "salary": salary})
    print("Salary added successfully!")

def view_salaries():
    if not salaries:
        print("No salaries in the record.")
    else:
        for i, salary in enumerate(salaries, start=1):
            print(f"Salary {i}:")
            for key, value in salary.items():
                print(f"  {key}: {value}")
            print()

def main():
    while True:
        print("1. Add Salary")
        print("2. View Salaries")
        print("3. Exit")
        choice = input("Enter your choice: ")
        if choice == '1':
            add_salary()
        elif choice == '2':
            view_salaries()
        elif choice == '3':
            print("Thank you for using the Salary Management System. Goodbye!")
            break
        else:
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    main()

# %%
#Question-108:To create marksheet generation system.
marksheets = []

def add_marksheet():
    student_name = input("Enter student name: ")
    subject = input("Enter subject: ")
    marks = float(input("Enter marks: "))
    marksheets.append({"student_name": student_name, "subject": subject, "marks": marks})
    print("Marksheet added successfully!")

def view_marksheets():
    if not marksheets:
        print("No marksheets in the record.")
    else:
        for i, marksheet in enumerate(marksheets, start=1):
            print(f"MarkSheet {i}:")
            for key, value in marksheet.items():
                print(f"  {key}: {value}")
            print()

def main():
    while True:
        print("1. Add MarkSheet")
        print("2. View MarkSheets")
        print("3. Exit")
        choice = input("Enter your choice: ")
        if choice == '1':
            add_marksheet()
        elif choice == '2':
            view_marksheets()
        elif choice == '3':
            print("Thank you for using the MarkSheet Generation System. Goodbye!")
            break
        else:
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    main()
